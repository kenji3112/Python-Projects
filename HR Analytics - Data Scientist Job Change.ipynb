# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import csv file & create a dataframe
df = pd.read_csv(r"C:\Users\kenji\Downloads\Compressed\aug_test.csv")

# %%
# display dataframe
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
# show top 5 rows
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
# show # of columns & rows
df.shape
# Out:
# (2129, 13)

# %%
# show dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.4+ KB

# %%
# perform statistic deviation
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours
# count   2129.000000             2129.000000     2129.000000
# mean   16861.614843                0.824984       64.983091
# std     9576.846029                0.125074       60.238660
# min        3.000000                0.448000        1.000000
# 25%     8562.000000                0.698000       23.000000
# 50%    16816.000000                0.903000       47.000000
# 75%    25129.000000                0.920000       86.000000
# max    33353.000000                0.949000      334.000000

# %%
# show data types
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# dtype: object

# %%
# check for duplicates
df.duplicated().any()
# Out:
# False

# %%
# rename column
df = df.rename(columns = {'relevent_experience': 'relevant_experience'})

# %%
df['relevant_experience'].replace('Has relevent experience', 'Has relevant experience', inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
# replace text
df['relevant_experience'].replace('No relevent experience', 'No relevant experience', inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevant_experience enrolled_university education_level  \
# 0  Has relevant experience    Full time course        Graduate
# 1  Has relevant experience       no_enrollment        Graduate
# 2   No relevant experience       no_enrollment     High School
# 3  Has relevant experience       no_enrollment         Masters
# 4  Has relevant experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
# replace missing values
df.fillna({'gender': 'Other', 'education_level': 'Other', 'major_discipline': 'Other', 'enrolled_university': 'no_enrollment','company_type': 'Other'}, inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
# check for count of null values
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                      0
# relevant_experience         0
# enrolled_university         0
# education_level             0
# major_discipline            0
# experience                  5
# company_size              622
# company_type                0
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
# check for null values in company size column
df[df['company_size'].isnull()]
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 5             217   city_23                   0.899    Male
# 7           27302  city_160                   0.920  Female
# 8           12994  city_173                   0.878    Male
# ...           ...       ...                     ...     ...
# 2122        24507   city_90                   0.698   Other
# 2123        21339   city_21                   0.624  Female
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
#
#           relevant_experience enrolled_university education_level  \
# 1     Has relevant experience       no_enrollment        Graduate
# 2      No relevant experience       no_enrollment     High School
# ...

# %%
 # replace null values with unknown 
df['company_size'].fillna('Unknown', inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                0
# city                       0
# city_development_index     0
# gender                     0
# relevant_experience        0
# enrolled_university        0
# education_level            0
# major_discipline           0
# experience                 5
# company_size               0
# company_type               0
# last_new_job              40
# training_hours             0
# dtype: int64

# %%
df[df['last_new_job'].isnull()]
# Out:
#       enrollee_id      city  city_development_index gender  \
# 29          19437   city_21                   0.624  Other
# 53           4742  city_149                   0.689  Other
# 125          4417  city_103                   0.920  Other
# 129         24230   city_21                   0.624  Other
# 149         20948   city_44                   0.725  Other
# 178          5391  city_155                   0.556   Male
# 215         23969   city_30                   0.698   Male
# 225         12361   city_21                   0.624  Other
# 226         15165  city_160                   0.920  Other
# 289         12391   city_99                   0.915  Other
# 305         28936   city_90                   0.698   Male
# 331          7770  city_103                   0.920  Other
# 413         21423   city_21                   0.624  Other
# 533         31483   city_10                   0.895  Other
# 557          2892   city_41                   0.827  Other
# ...

# %%
df['last_new_job'].fillna('Unknown', inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
# show count of null values
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                      0
# relevant_experience         0
# enrolled_university         0
# education_level             0
# major_discipline            0
# experience                  5
# company_size              622
# company_type                0
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
# replace NaN values
df['experience'].fillna('Unknown', inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
# filter values that contain /
df[df['company_size'].str.contains('/')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[438], line 2
#       1 # filter values that contain /
# ----> 2 df[df['company_size'].str.contains('/')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
# ...

# %%
# replace / with -
df['company_size'].replace('10/49','10-49', inplace = True)

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevant_experience enrolled_university education_level  \
# 0     Has relevant experience    Full time course        Graduate
# 1     Has relevant experience       no_enrollment        Graduate
# ...

# %%
df[df['company_size'].str.contains('-')]
# Out:
#       enrollee_id      city  city_development_index gender  \
# 3           27385   city_13                   0.827   Male
# 6           21465   city_21                   0.624  Other
# 9           16287   city_21                   0.624   Male
# 11           9272   city_90                   0.698   Male
# 12          14249   city_46                   0.762   Male
# ...           ...       ...                     ...    ...
# 2113        10726   city_71                   0.884   Male
# 2114         6294   city_73                   0.754  Other
# 2115        13833   city_21                   0.624   Male
# 2116        31643   city_75                   0.939   Male
# 2127         7873  city_102                   0.804   Male
#
#           relevant_experience enrolled_university education_level  \
# 3     Has relevant experience       no_enrollment         Masters
# 6     Has relevant experience       no_enrollment        Graduate
# ...

# %%
df.head
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevant_experience enrolled_university education_level  \
# 0  Has relevant experience    Full time course        Graduate
# 1  Has relevant experience       no_enrollment        Graduate
# 2   No relevant experience       no_enrollment     High School
# 3  Has relevant experience       no_enrollment         Masters
# 4  Has relevant experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10        Other            1
# 1             STEM          5      Unknown      Pvt Ltd            1
# ...

# %% [markdown]
# # City Development and Employment

# %%
df.plot.scatter(x = 'gender', y = 'city_development_index', s = 100, c = 'black')
# Out:
# <Axes: xlabel='gender', ylabel='city_development_index'>

# %%
df.plot.scatter(x = 'company_type', y = 'city_development_index', s = 50, c = 'black', figsize = (10, 5))
# Out:
# <Axes: xlabel='company_type', ylabel='city_development_index'>

# %% [markdown]
# # Gender Distribution

# %%
df.hist('gender', by = 'education_level', figsize = (10,10))
# Out:
# array([[<Axes: title={'center': 'Graduate'}>,
#         <Axes: title={'center': 'High School'}>],
#        [<Axes: title={'center': 'Masters'}>,
#         <Axes: title={'center': 'Other'}>],
#        [<Axes: title={'center': 'Phd'}>,
#         <Axes: title={'center': 'Primary School'}>]], dtype=object)

# %%
df.hist('gender', by = 'relevant_experience', figsize = (10,5))
# Out:
# array([<Axes: title={'center': 'Has relevant experience'}>,
#        <Axes: title={'center': 'No relevant experience'}>], dtype=object)

# %%
df.hist('gender', by = 'company_size', figsize = (10,10))
# Out:
# array([[<Axes: title={'center': '10-49'}>,
#         <Axes: title={'center': '100-500'}>,
#         <Axes: title={'center': '1000-4999'}>],
#        [<Axes: title={'center': '10000+'}>,
#         <Axes: title={'center': '50-99'}>,
#         <Axes: title={'center': '500-999'}>],
#        [<Axes: title={'center': '5000-9999'}>,
#         <Axes: title={'center': '<10'}>,
#         <Axes: title={'center': 'Unknown'}>]], dtype=object)

# %% [markdown]
# # Experience and Education

# %%
df.plot.scatter(x = 'education_level', y = 'experience', s = 50, c = 'black', figsize = (10, 5))
# Out:
# <Axes: xlabel='education_level', ylabel='experience'>

# %%
df.plot.scatter(x = 'major_discipline', y = 'experience', s = 50, c = 'black', figsize = (10, 5))
# Out:
# <Axes: xlabel='major_discipline', ylabel='experience'>

# %% [markdown]
# # Company Size and Type

# %%
df.hist('enrollee_id', by = 'company_type', figsize = (10,10))
# Out:
# array([[<Axes: title={'center': 'Early Stage Startup'}>,
#         <Axes: title={'center': 'Funded Startup'}>],
#        [<Axes: title={'center': 'NGO'}>,
#         <Axes: title={'center': 'Other'}>],
#        [<Axes: title={'center': 'Public Sector'}>,
#         <Axes: title={'center': 'Pvt Ltd'}>]], dtype=object)

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevant_experience enrolled_university education_level  \
# 0  Has relevant experience    Full time course        Graduate
# 1  Has relevant experience       no_enrollment        Graduate
# 2   No relevant experience       no_enrollment     High School
# 3  Has relevant experience       no_enrollment         Masters
# 4  Has relevant experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10        Other            1
# 1             STEM          5      Unknown      Pvt Ltd            1
# ...

# %% [markdown]
# # Training Hours

# %%
df.plot.scatter(x = 'education_level', y = 'training_hours', s = 50, c = 'black', figsize = (10, 5))
# Out:
# <Axes: xlabel='education_level', ylabel='training_hours'>

# %%
df.plot.scatter(x = 'experience', y = 'training_hours', s = 50, c = 'black', figsize = (12, 5))
# Out:
# <Axes: xlabel='experience', ylabel='training_hours'>

# %%
df.plot.scatter(x = 'last_new_job', y = 'training_hours', s = 50, c = 'black', figsize = (10, 5))
# Out:
# <Axes: xlabel='last_new_job', ylabel='training_hours'>
